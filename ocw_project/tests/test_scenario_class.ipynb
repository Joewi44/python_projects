# %% [markdown]
# # Check behavior of scenario with globaal_index

# %%
# %load_ext autoreload
# %autoreload 2
from ocw_project.Maintenance_Manager import MaintenanceManager

# Current and previous G values
G_min1 = 0.51
G = 0.29

# Get maintenance recommendation
result = MaintenanceManager.get_maintenance_type(G, G_min1, scenario_id=16)
print(f"Maintenance type: {result}")  # Output depends on your thresholds

# See all scenarios
print("\nAvailable scenarios:")
for sc_id, sc in MaintenanceManager.list_scenarios().items():
    print(f"Scenario {sc_id}: R={sc.routine}, L={sc.lokaal}, Alg_1={sc.algemeen_v1}, Alg_2={sc.algemeen_v2}, Alg_3={sc.algemeen_v3}")
# Out:
# Maintenance type: algemeen_v1
#
# Available scenarios:
# Scenario 1: R=0.9, L=0.8, Alg_1=nan, Alg_2=nan, Alg_3=0.5
# Scenario 2: R=0.9, L=0.8, Alg_1=nan, Alg_2=nan, Alg_3=0.5
# Scenario 3: R=0.9, L=0.8, Alg_1=nan, Alg_2=nan, Alg_3=0.5
# Scenario 4: R=0.9, L=0.8, Alg_1=nan, Alg_2=0.5, Alg_3=nan
# Scenario 5: R=0.9, L=0.8, Alg_1=nan, Alg_2=0.5, Alg_3=nan
# Scenario 6: R=0.9, L=0.8, Alg_1=nan, Alg_2=0.5, Alg_3=nan
# Scenario 7: R=0.9, L=0.8, Alg_1=0.5, Alg_2=nan, Alg_3=nan
# Scenario 8: R=0.9, L=0.8, Alg_1=0.5, Alg_2=nan, Alg_3=nan
# Scenario 9: R=0.9, L=0.8, Alg_1=0.5, Alg_2=nan, Alg_3=nan
# Scenario 10: R=0.9, L=[0.8, 0.5], Alg_1=nan, Alg_2=nan, Alg_3=nan
# Scenario 11: R=0.9, L=[0.8, 0.5], Alg_1=nan, Alg_2=nan, Alg_3=nan
# Scenario 12: R=0.9, L=[0.8, 0.5], Alg_1=nan, Alg_2=nan, Alg_3=nan
# Scenario 13: R=0.9, L=0.8, Alg_1=nan, Alg_2=nan, Alg_3=[0.5, 0.3]
# Scenario 14: R=0.9, L=0.8, Alg_1=nan, Alg_2=[0.5, 0.3], Alg_3=nan
# Scenario 15: R=0.9, L=0.8, Alg_1=0.5, Alg_2=nan, Alg_3=0.3
# ...
